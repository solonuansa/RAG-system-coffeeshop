# %%
# %uv pip install -U accelerate bitsandbytes
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Resolved 47 packages in 218ms
# ⠙ Preparing packages... (0/40)
# ⠙ Preparing packages... (0/40)
# ⠙ Preparing packages... (0/40)
# certifi    ------------------------------     0 B/149.32 KiB
# ⠙ Preparing packages... (0/40)
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# anyio      ------------------------------     0 B/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# click      ------------------------------     0 B/105.74 KiB
# anyio      ------------------------------     0 B/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# tqdm       ------------------------------     0 B/76.54 KiB
# click      ------------------------------     0 B/105.74 KiB
# anyio      ------------------------------     0 B/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# packaging  ------------------------------     0 B/72.62 KiB
# tqdm       ------------------------------     0 B/76.54 KiB
# click      ------------------------------     0 B/105.74 KiB
# anyio      ------------------------------     0 B/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# idna       ------------------------------     0 B/69.34 KiB
# packaging  ------------------------------     0 B/72.62 KiB
# tqdm       ------------------------------     0 B/76.54 KiB
# click      ------------------------------     0 B/105.74 KiB
# anyio      ------------------------------     0 B/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# typing-extensions ------------------------------     0 B/43.57 KiB
# idna       ------------------------------     0 B/69.34 KiB
# packaging  ------------------------------     0 B/72.62 KiB
# tqdm       ------------------------------     0 B/76.54 KiB
# click      ------------------------------     0 B/105.74 KiB
# anyio      ------------------------------     0 B/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------     0 B/16.31 KiB
# typing-extensions ------------------------------     0 B/43.57 KiB
# idna       ------------------------------     0 B/69.34 KiB
# packaging  ------------------------------     0 B/72.62 KiB
# tqdm       ------------------------------     0 B/76.54 KiB
# click      ------------------------------     0 B/105.74 KiB
# anyio      ------------------------------     0 B/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------     0 B/16.31 KiB
# typing-extensions ------------------------------     0 B/43.57 KiB
# idna       ------------------------------     0 B/69.34 KiB
# packaging  ------------------------------     0 B/72.62 KiB
# tqdm       ------------------------------     0 B/76.54 KiB
# click      ------------------------------     0 B/105.74 KiB
# anyio      ------------------------------ 14.89 KiB/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------     0 B/16.31 KiB
# typing-extensions ------------------------------     0 B/43.57 KiB
# idna       ------------------------------     0 B/69.34 KiB
# packaging  ------------------------------     0 B/72.62 KiB
# tqdm       ------------------------------     0 B/76.54 KiB
# click      ------------------------------ 14.86 KiB/105.74 KiB
# anyio      ------------------------------ 14.89 KiB/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------     0 B/16.31 KiB
# typing-extensions ------------------------------     0 B/43.57 KiB
# idna       ------------------------------     0 B/69.34 KiB
# packaging  ------------------------------     0 B/72.62 KiB
# tqdm       ------------------------------ 14.89 KiB/76.54 KiB
# click      ------------------------------ 14.86 KiB/105.74 KiB
# anyio      ------------------------------ 14.89 KiB/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------     0 B/16.31 KiB
# typing-extensions ------------------------------     0 B/43.57 KiB
# idna       ------------------------------     0 B/69.34 KiB
# packaging  ------------------------------ 14.89 KiB/72.62 KiB
# tqdm       ------------------------------ 14.89 KiB/76.54 KiB
# click      ------------------------------ 14.86 KiB/105.74 KiB
# anyio      ------------------------------ 14.89 KiB/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------     0 B/16.31 KiB
# typing-extensions ------------------------------     0 B/43.57 KiB
# idna       ------------------------------ 14.86 KiB/69.34 KiB
# packaging  ------------------------------ 14.89 KiB/72.62 KiB
# tqdm       ------------------------------ 14.89 KiB/76.54 KiB
# click      ------------------------------ 14.86 KiB/105.74 KiB
# anyio      ------------------------------ 14.89 KiB/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------     0 B/16.31 KiB
# typing-extensions ------------------------------ 14.88 KiB/43.57 KiB
# idna       ------------------------------ 14.86 KiB/69.34 KiB
# packaging  ------------------------------ 14.89 KiB/72.62 KiB
# tqdm       ------------------------------ 14.89 KiB/76.54 KiB
# click      ------------------------------ 14.86 KiB/105.74 KiB
# anyio      ------------------------------ 14.89 KiB/110.93 KiB
# certifi    ------------------------------ 14.89 KiB/149.32 KiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------ 14.87 KiB/16.31 KiB
# markupsafe ------------------------------ 14.88 KiB/22.41 KiB
# cuda-pathfinder ------------------------------ 14.91 KiB/26.52 KiB
# typing-extensions ------------------------------ 43.57 KiB/43.57 KiB
# typer-slim ------------------------------ 14.92 KiB/46.33 KiB
# idna       ------------------------------ 14.86 KiB/69.34 KiB
# packaging  ------------------------------ 14.89 KiB/72.62 KiB
# tqdm       ------------------------------ 14.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 14.91 KiB/87.85 KiB
# click      ------------------------------ 14.86 KiB/105.74 KiB
# anyio      ------------------------------ 14.89 KiB/110.93 KiB
# jinja2     ------------------------------ 14.89 KiB/131.74 KiB
# certifi    ------------------------------ 149.32 KiB/149.32 KiB
# psutil     ------------------------------ 38.94 KiB/151.91 KiB
# fsspec     ------------------------------ 14.92 KiB/197.11 KiB
# accelerate ------------------------------ 46.89 KiB/372.01 KiB
# safetensors ------------------------------ 14.88 KiB/495.27 KiB
# huggingface-hub ------------------------------ 26.22 KiB/524.15 KiB
# pyyaml     ------------------------------ 14.89 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 14.90 KiB/932.39 KiB
# setuptools ------------------------------ 14.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 14.91 KiB/1.14 MiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------ 14.87 KiB/16.31 KiB
# markupsafe ------------------------------ 22.41 KiB/22.41 KiB
# cuda-pathfinder ------------------------------ 14.91 KiB/26.52 KiB
# typer-slim ------------------------------ 14.92 KiB/46.33 KiB
# idna       ------------------------------ 30.86 KiB/69.34 KiB
# packaging  ------------------------------ 14.89 KiB/72.62 KiB
# tqdm       ------------------------------ 14.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 30.91 KiB/87.85 KiB
# click      ------------------------------ 62.86 KiB/105.74 KiB
# anyio      ------------------------------ 30.89 KiB/110.93 KiB
# jinja2     ------------------------------ 30.89 KiB/131.74 KiB
# certifi    ------------------------------ 149.32 KiB/149.32 KiB
# psutil     ------------------------------ 70.94 KiB/151.91 KiB
# fsspec     ------------------------------ 30.92 KiB/197.11 KiB
# accelerate ------------------------------ 78.89 KiB/372.01 KiB
# safetensors ------------------------------ 14.88 KiB/495.27 KiB
# huggingface-hub ------------------------------ 42.22 KiB/524.15 KiB
# pyyaml     ------------------------------ 222.89 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 14.90 KiB/932.39 KiB
# setuptools ------------------------------ 46.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 222.05 KiB/1.14 MiB
# networkx   ------------------------------ 30.86 KiB/1.97 MiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------ 14.87 KiB/16.31 KiB
# markupsafe ------------------------------ 22.41 KiB/22.41 KiB
# cuda-pathfinder ------------------------------ 14.91 KiB/26.52 KiB
# typer-slim ------------------------------ 14.92 KiB/46.33 KiB
# idna       ------------------------------ 30.86 KiB/69.34 KiB
# packaging  ------------------------------ 30.89 KiB/72.62 KiB
# tqdm       ------------------------------ 14.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 30.91 KiB/87.85 KiB
# click      ------------------------------ 62.86 KiB/105.74 KiB
# anyio      ------------------------------ 30.89 KiB/110.93 KiB
# jinja2     ------------------------------ 30.89 KiB/131.74 KiB
# certifi    ------------------------------ 149.32 KiB/149.32 KiB
# psutil     ------------------------------ 78.86 KiB/151.91 KiB
# fsspec     ------------------------------ 30.92 KiB/197.11 KiB
# accelerate ------------------------------ 78.89 KiB/372.01 KiB
# safetensors ------------------------------ 14.88 KiB/495.27 KiB
# huggingface-hub ------------------------------ 42.22 KiB/524.15 KiB
# pyyaml     ------------------------------ 222.89 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 30.90 KiB/932.39 KiB
# setuptools ------------------------------ 46.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 222.05 KiB/1.14 MiB
# networkx   ------------------------------ 30.86 KiB/1.97 MiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------ 14.87 KiB/16.31 KiB
# markupsafe ------------------------------ 22.41 KiB/22.41 KiB
# cuda-pathfinder ------------------------------ 14.91 KiB/26.52 KiB
# typer-slim ------------------------------ 30.92 KiB/46.33 KiB
# idna       ------------------------------ 69.34 KiB/69.34 KiB
# packaging  ------------------------------ 30.89 KiB/72.62 KiB
# tqdm       ------------------------------ 14.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 46.91 KiB/87.85 KiB
# click      ------------------------------ 62.86 KiB/105.74 KiB
# anyio      ------------------------------ 46.89 KiB/110.93 KiB
# jinja2     ------------------------------ 46.89 KiB/131.74 KiB
# psutil     ------------------------------ 142.86 KiB/151.91 KiB
# fsspec     ------------------------------ 46.92 KiB/197.11 KiB
# accelerate ------------------------------ 94.89 KiB/372.01 KiB
# safetensors ------------------------------ 30.88 KiB/495.27 KiB
# huggingface-hub ------------------------------ 58.22 KiB/524.15 KiB
# pyyaml     ------------------------------ 270.89 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 222.90 KiB/932.39 KiB
# setuptools ------------------------------ 46.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 302.05 KiB/1.14 MiB
# networkx   ------------------------------ 30.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 318.89 KiB/3.17 MiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------ 14.87 KiB/16.31 KiB
# markupsafe ------------------------------ 22.41 KiB/22.41 KiB
# cuda-pathfinder ------------------------------ 26.52 KiB/26.52 KiB
# typer-slim ------------------------------ 30.92 KiB/46.33 KiB
# idna       ------------------------------ 69.34 KiB/69.34 KiB
# packaging  ------------------------------ 46.89 KiB/72.62 KiB
# tqdm       ------------------------------ 14.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 46.91 KiB/87.85 KiB
# click      ------------------------------ 78.86 KiB/105.74 KiB
# anyio      ------------------------------ 46.89 KiB/110.93 KiB
# jinja2     ------------------------------ 78.89 KiB/131.74 KiB
# psutil     ------------------------------ 142.86 KiB/151.91 KiB
# fsspec     ------------------------------ 46.92 KiB/197.11 KiB
# accelerate ------------------------------ 94.89 KiB/372.01 KiB
# safetensors ------------------------------ 30.88 KiB/495.27 KiB
# huggingface-hub ------------------------------ 74.22 KiB/524.15 KiB
# pyyaml     ------------------------------ 334.89 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 222.90 KiB/932.39 KiB
# setuptools ------------------------------ 62.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 376.81 KiB/1.14 MiB
# networkx   ------------------------------ 30.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 382.78 KiB/3.17 MiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------ 14.87 KiB/16.31 KiB
# cuda-pathfinder ------------------------------ 26.52 KiB/26.52 KiB
# typer-slim ------------------------------ 30.92 KiB/46.33 KiB
# idna       ------------------------------ 69.34 KiB/69.34 KiB
# packaging  ------------------------------ 46.89 KiB/72.62 KiB
# tqdm       ------------------------------ 14.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 46.91 KiB/87.85 KiB
# click      ------------------------------ 78.86 KiB/105.74 KiB
# anyio      ------------------------------ 46.89 KiB/110.93 KiB
# jinja2     ------------------------------ 78.89 KiB/131.74 KiB
# psutil     ------------------------------ 151.91 KiB/151.91 KiB
# fsspec     ------------------------------ 46.92 KiB/197.11 KiB
# accelerate ------------------------------ 94.89 KiB/372.01 KiB
# safetensors ------------------------------ 30.88 KiB/495.27 KiB
# huggingface-hub ------------------------------ 74.22 KiB/524.15 KiB
# pyyaml     ------------------------------ 334.89 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 238.90 KiB/932.39 KiB
# setuptools ------------------------------ 62.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 376.81 KiB/1.14 MiB
# networkx   ------------------------------ 46.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 382.78 KiB/3.17 MiB
# sympy      ------------------------------ 31.89 KiB/6.01 MiB
# ⠙ Preparing packages... (0/40)
# filelock   ------------------------------ 16.31 KiB/16.31 KiB
# cuda-pathfinder ------------------------------ 26.52 KiB/26.52 KiB
# typer-slim ------------------------------ 46.33 KiB/46.33 KiB
# packaging  ------------------------------ 62.89 KiB/72.62 KiB
# tqdm       ------------------------------ 14.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 46.91 KiB/87.85 KiB
# click      ------------------------------ 94.86 KiB/105.74 KiB
# anyio      ------------------------------ 62.78 KiB/110.93 KiB
# jinja2     ------------------------------ 78.89 KiB/131.74 KiB
# psutil     ------------------------------ 151.91 KiB/151.91 KiB
# fsspec     ------------------------------ 46.92 KiB/197.11 KiB
# accelerate ------------------------------ 94.89 KiB/372.01 KiB
# safetensors ------------------------------ 446.04 KiB/495.27 KiB
# huggingface-hub ------------------------------ 74.22 KiB/524.15 KiB
# pyyaml     ------------------------------ 392.56 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 238.90 KiB/932.39 KiB
# setuptools ------------------------------ 62.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 414.05 KiB/1.14 MiB
# networkx   ------------------------------ 46.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 425.61 KiB/3.17 MiB
# sympy      ------------------------------ 31.89 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 96.00 KiB/9.77 MiB
# ⠙ Preparing packages... (0/40)
# cuda-pathfinder ------------------------------ 26.52 KiB/26.52 KiB
# typer-slim ------------------------------ 46.33 KiB/46.33 KiB
# packaging  ------------------------------ 62.89 KiB/72.62 KiB
# tqdm       ------------------------------ 14.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 46.91 KiB/87.85 KiB
# click      ------------------------------ 94.86 KiB/105.74 KiB
# anyio      ------------------------------ 62.78 KiB/110.93 KiB
# jinja2     ------------------------------ 94.89 KiB/131.74 KiB
# psutil     ------------------------------ 151.91 KiB/151.91 KiB
# fsspec     ------------------------------ 46.92 KiB/197.11 KiB
# accelerate ------------------------------ 110.89 KiB/372.01 KiB
# safetensors ------------------------------ 446.04 KiB/495.27 KiB
# huggingface-hub ------------------------------ 74.22 KiB/524.15 KiB
# pyyaml     ------------------------------ 392.56 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 238.90 KiB/932.39 KiB
# setuptools ------------------------------ 62.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 414.05 KiB/1.14 MiB
# networkx   ------------------------------ 46.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 425.61 KiB/3.17 MiB
# sympy      ------------------------------ 31.89 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 112.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 142.91 KiB/11.59 MiB
# ⠙ Preparing packages... (0/40)
# cuda-pathfinder ------------------------------ 26.52 KiB/26.52 KiB
# typer-slim ------------------------------ 46.33 KiB/46.33 KiB
# packaging  ------------------------------ 72.62 KiB/72.62 KiB
# tqdm       ------------------------------ 30.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 55.63 KiB/87.85 KiB
# click      ------------------------------ 105.04 KiB/105.74 KiB
# anyio      ------------------------------ 62.78 KiB/110.93 KiB
# jinja2     ------------------------------ 94.89 KiB/131.74 KiB
# fsspec     ------------------------------ 62.92 KiB/197.11 KiB
# accelerate ------------------------------ 126.78 KiB/372.01 KiB
# safetensors ------------------------------ 493.89 KiB/495.27 KiB
# huggingface-hub ------------------------------ 94.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 440.56 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 254.90 KiB/932.39 KiB
# setuptools ------------------------------ 62.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 478.05 KiB/1.14 MiB
# networkx   ------------------------------ 62.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 488.56 KiB/3.17 MiB
# sympy      ------------------------------ 47.89 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 112.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 190.91 KiB/11.59 MiB
# numpy      ------------------------------ 80.00 KiB/15.85 MiB
# ⠙ Preparing packages... (0/40)
# cuda-pathfinder ------------------------------ 26.52 KiB/26.52 KiB
# typer-slim ------------------------------ 46.33 KiB/46.33 KiB
# packaging  ------------------------------ 72.62 KiB/72.62 KiB
# tqdm       ------------------------------ 30.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 55.63 KiB/87.85 KiB
# click      ------------------------------ 105.04 KiB/105.74 KiB
# anyio      ------------------------------ 62.78 KiB/110.93 KiB
# jinja2     ------------------------------ 110.89 KiB/131.74 KiB
# fsspec     ------------------------------ 62.92 KiB/197.11 KiB
# accelerate ------------------------------ 126.78 KiB/372.01 KiB
# safetensors ------------------------------ 493.89 KiB/495.27 KiB
# huggingface-hub ------------------------------ 94.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 456.56 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 254.90 KiB/932.39 KiB
# setuptools ------------------------------ 62.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 478.05 KiB/1.14 MiB
# networkx   ------------------------------ 62.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 488.56 KiB/3.17 MiB
# sympy      ------------------------------ 47.89 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 128.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 222.05 KiB/11.59 MiB
# numpy      ------------------------------ 80.00 KiB/15.85 MiB
# ⠹ Preparing packages... (6/40)
# cuda-pathfinder ------------------------------ 26.52 KiB/26.52 KiB
# typer-slim ------------------------------ 46.33 KiB/46.33 KiB
# packaging  ------------------------------ 72.62 KiB/72.62 KiB
# tqdm       ------------------------------ 46.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 73.21 KiB/87.85 KiB
# click      ------------------------------ 105.04 KiB/105.74 KiB
# anyio      ------------------------------ 78.78 KiB/110.93 KiB
# jinja2     ------------------------------ 110.89 KiB/131.74 KiB
# fsspec     ------------------------------ 78.92 KiB/197.11 KiB
# accelerate ------------------------------ 126.78 KiB/372.01 KiB
# huggingface-hub ------------------------------ 190.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 488.56 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 270.90 KiB/932.39 KiB
# setuptools ------------------------------ 62.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 526.05 KiB/1.14 MiB
# networkx   ------------------------------ 62.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 536.56 KiB/3.17 MiB
# sympy      ------------------------------ 47.89 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 128.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 238.05 KiB/11.59 MiB
# numpy      ------------------------------ 80.00 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 558.05 KiB/37.44 MiB
# ⠹ Preparing packages... (6/40)
# cuda-pathfinder ------------------------------ 26.52 KiB/26.52 KiB
# packaging  ------------------------------ 72.62 KiB/72.62 KiB
# tqdm       ------------------------------ 46.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 73.21 KiB/87.85 KiB
# click      ------------------------------ 105.74 KiB/105.74 KiB
# anyio      ------------------------------ 78.78 KiB/110.93 KiB
# jinja2     ------------------------------ 126.89 KiB/131.74 KiB
# fsspec     ------------------------------ 94.92 KiB/197.11 KiB
# accelerate ------------------------------ 142.78 KiB/372.01 KiB
# huggingface-hub ------------------------------ 206.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 504.56 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 302.90 KiB/932.39 KiB
# setuptools ------------------------------ 62.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 526.05 KiB/1.14 MiB
# networkx   ------------------------------ 94.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 536.56 KiB/3.17 MiB
# sympy      ------------------------------ 57.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 144.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 270.05 KiB/11.59 MiB
# numpy      ------------------------------ 96.00 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 558.05 KiB/37.44 MiB
# bitsandbytes ------------------------------ 524.80 KiB/56.32 MiB
# ⠹ Preparing packages... (6/40)
# packaging  ------------------------------ 72.62 KiB/72.62 KiB
# tqdm       ------------------------------ 46.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 73.21 KiB/87.85 KiB
# click      ------------------------------ 105.74 KiB/105.74 KiB
# anyio      ------------------------------ 78.78 KiB/110.93 KiB
# jinja2     ------------------------------ 126.89 KiB/131.74 KiB
# fsspec     ------------------------------ 94.92 KiB/197.11 KiB
# accelerate ------------------------------ 142.78 KiB/372.01 KiB
# huggingface-hub ------------------------------ 206.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 504.56 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 302.90 KiB/932.39 KiB
# setuptools ------------------------------ 62.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 526.05 KiB/1.14 MiB
# networkx   ------------------------------ 94.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 536.56 KiB/3.17 MiB
# sympy      ------------------------------ 57.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 144.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 270.05 KiB/11.59 MiB
# numpy      ------------------------------ 96.00 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 558.05 KiB/37.44 MiB
# bitsandbytes ------------------------------ 524.80 KiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 493.32 KiB/60.67 MiB
# ⠹ Preparing packages... (6/40)
# packaging  ------------------------------ 72.62 KiB/72.62 KiB
# tqdm       ------------------------------ 46.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 73.21 KiB/87.85 KiB
# anyio      ------------------------------ 78.78 KiB/110.93 KiB
# jinja2     ------------------------------ 126.89 KiB/131.74 KiB
# fsspec     ------------------------------ 94.92 KiB/197.11 KiB
# accelerate ------------------------------ 142.78 KiB/372.01 KiB
# huggingface-hub ------------------------------ 222.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 504.56 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 302.90 KiB/932.39 KiB
# setuptools ------------------------------ 62.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 526.05 KiB/1.14 MiB
# networkx   ------------------------------ 94.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 536.56 KiB/3.17 MiB
# sympy      ------------------------------ 57.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 144.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 270.05 KiB/11.59 MiB
# numpy      ------------------------------ 96.00 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 558.05 KiB/37.44 MiB
# bitsandbytes ------------------------------ 524.80 KiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 493.32 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 520.56 KiB/83.96 MiB
# ⠹ Preparing packages... (6/40)
# tqdm       ------------------------------ 46.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 73.21 KiB/87.85 KiB
# anyio      ------------------------------ 78.78 KiB/110.93 KiB
# jinja2     ------------------------------ 126.89 KiB/131.74 KiB
# fsspec     ------------------------------ 94.92 KiB/197.11 KiB
# accelerate ------------------------------ 142.78 KiB/372.01 KiB
# huggingface-hub ------------------------------ 222.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 536.46 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 318.90 KiB/932.39 KiB
# setuptools ------------------------------ 78.75 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 558.05 KiB/1.14 MiB
# networkx   ------------------------------ 110.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 568.56 KiB/3.17 MiB
# sympy      ------------------------------ 64.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 144.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 270.05 KiB/11.59 MiB
# numpy      ------------------------------ 96.00 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 606.05 KiB/37.44 MiB
# bitsandbytes ------------------------------ 566.13 KiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 536.56 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 568.56 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 46.83 KiB/132.66 MiB
# ⠹ Preparing packages... (6/40)
# tqdm       ------------------------------ 46.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 87.85 KiB/87.85 KiB
# anyio      ------------------------------ 94.89 KiB/110.93 KiB
# jinja2     ------------------------------ 126.89 KiB/131.74 KiB
# fsspec     ------------------------------ 110.92 KiB/197.11 KiB
# accelerate ------------------------------ 142.78 KiB/372.01 KiB
# huggingface-hub ------------------------------ 228.96 KiB/524.15 KiB
# pyyaml     ------------------------------ 568.46 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 350.90 KiB/932.39 KiB
# setuptools ------------------------------ 78.75 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 601.19 KiB/1.14 MiB
# networkx   ------------------------------ 110.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 600.56 KiB/3.17 MiB
# sympy      ------------------------------ 64.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 144.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 478.05 KiB/11.59 MiB
# numpy      ------------------------------ 96.00 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 624.61 KiB/37.44 MiB
# bitsandbytes ------------------------------ 588.80 KiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 568.56 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 600.56 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 46.83 KiB/132.66 MiB
# ⠹ Preparing packages... (6/40)
# tqdm       ------------------------------ 62.89 KiB/76.54 KiB
# nvidia-nvtx-cu12 ------------------------------ 87.85 KiB/87.85 KiB
# anyio      ------------------------------ 94.89 KiB/110.93 KiB
# fsspec     ------------------------------ 110.92 KiB/197.11 KiB
# accelerate ------------------------------ 158.89 KiB/372.01 KiB
# huggingface-hub ------------------------------ 244.96 KiB/524.15 KiB
# pyyaml     ------------------------------ 632.46 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 366.90 KiB/932.39 KiB
# setuptools ------------------------------ 78.75 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 654.05 KiB/1.14 MiB
# networkx   ------------------------------ 126.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 664.56 KiB/3.17 MiB
# sympy      ------------------------------ 80.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 160.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 654.05 KiB/11.59 MiB
# numpy      ------------------------------ 160.00 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 701.94 KiB/37.44 MiB
# bitsandbytes ------------------------------ 652.80 KiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 639.84 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 662.76 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 46.83 KiB/132.66 MiB
# triton     ------------------------------ 683.53 KiB/179.55 MiB
# ⠹ Preparing packages... (6/40)
# tqdm       ------------------------------ 62.89 KiB/76.54 KiB
# anyio      ------------------------------ 94.89 KiB/110.93 KiB
# fsspec     ------------------------------ 110.92 KiB/197.11 KiB
# accelerate ------------------------------ 158.89 KiB/372.01 KiB
# huggingface-hub ------------------------------ 244.96 KiB/524.15 KiB
# pyyaml     ------------------------------ 648.46 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 386.73 KiB/932.39 KiB
# setuptools ------------------------------ 78.75 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 670.05 KiB/1.14 MiB
# networkx   ------------------------------ 126.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 680.56 KiB/3.17 MiB
# sympy      ------------------------------ 80.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 160.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 670.05 KiB/11.59 MiB
# numpy      ------------------------------ 160.00 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 717.94 KiB/37.44 MiB
# bitsandbytes ------------------------------ 668.80 KiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 648.56 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 678.76 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 62.83 KiB/132.66 MiB
# triton     ------------------------------ 699.53 KiB/179.55 MiB
# nvidia-cufft-cu12 ------------------------------ 704.88 KiB/184.17 MiB
# ⠹ Preparing packages... (6/40)
# tqdm       ------------------------------ 76.54 KiB/76.54 KiB
# anyio      ------------------------------ 94.89 KiB/110.93 KiB
# fsspec     ------------------------------ 142.92 KiB/197.11 KiB
# accelerate ------------------------------ 174.89 KiB/372.01 KiB
# huggingface-hub ------------------------------ 260.96 KiB/524.15 KiB
# pyyaml     ------------------------------ 680.56 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 408.56 KiB/932.39 KiB
# setuptools ------------------------------ 94.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 733.95 KiB/1.14 MiB
# networkx   ------------------------------ 142.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 719.62 KiB/3.17 MiB
# sympy      ------------------------------ 80.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 192.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 734.05 KiB/11.59 MiB
# numpy      ------------------------------ 160.00 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 750.05 KiB/37.44 MiB
# bitsandbytes ------------------------------ 716.80 KiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 712.56 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 728.56 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 78.83 KiB/132.66 MiB
# triton     ------------------------------ 763.53 KiB/179.55 MiB
# nvidia-cufft-cu12 ------------------------------ 753.66 KiB/184.17 MiB
# ⠹ Preparing packages... (6/40)
# anyio      ------------------------------ 110.89 KiB/110.93 KiB
# fsspec     ------------------------------ 158.92 KiB/197.11 KiB
# accelerate ------------------------------ 174.89 KiB/372.01 KiB
# huggingface-hub ------------------------------ 270.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 699.30 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 536.56 KiB/932.39 KiB
# setuptools ------------------------------ 110.75 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 749.95 KiB/1.14 MiB
# networkx   ------------------------------ 158.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 735.62 KiB/3.17 MiB
# sympy      ------------------------------ 80.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 192.00 KiB/9.77 MiB
# cuda-bindings ------------------------------ 750.05 KiB/11.59 MiB
# numpy      ------------------------------ 176.00 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 766.05 KiB/37.44 MiB
# bitsandbytes ------------------------------ 732.80 KiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 715.41 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 744.56 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 94.83 KiB/132.66 MiB
# triton     ------------------------------ 779.53 KiB/179.55 MiB
# nvidia-cufft-cu12 ------------------------------ 769.66 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 748.90 KiB/255.11 MiB
# ⠹ Preparing packages... (6/40)
# anyio      ------------------------------ 110.89 KiB/110.93 KiB
# fsspec     ------------------------------ 174.92 KiB/197.11 KiB
# accelerate ------------------------------ 192.71 KiB/372.01 KiB
# huggingface-hub ------------------------------ 302.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 760.56 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 536.56 KiB/932.39 KiB
# setuptools ------------------------------ 142.75 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 817.57 KiB/1.14 MiB
# networkx   ------------------------------ 174.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 820.47 KiB/3.17 MiB
# sympy      ------------------------------ 96.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 862.95 KiB/9.77 MiB
# cuda-bindings ------------------------------ 846.05 KiB/11.59 MiB
# numpy      ------------------------------ 249.81 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 878.05 KiB/37.44 MiB
# bitsandbytes ------------------------------ 813.73 KiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 806.68 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 840.56 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 126.83 KiB/132.66 MiB
# triton     ------------------------------ 891.53 KiB/179.55 MiB
# nvidia-cufft-cu12 ------------------------------ 856.56 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 845.96 KiB/255.11 MiB
# ⠹ Preparing packages... (6/40)
# fsspec     ------------------------------ 190.92 KiB/197.11 KiB
# accelerate ------------------------------ 192.71 KiB/372.01 KiB
# huggingface-hub ------------------------------ 334.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 776.56 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 536.56 KiB/932.39 KiB
# setuptools ------------------------------ 158.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 894.05 KiB/1.14 MiB
# networkx   ------------------------------ 190.86 KiB/1.97 MiB
# hf-xet     ------------------------------ 880.30 KiB/3.17 MiB
# sympy      ------------------------------ 112.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 916.71 KiB/9.77 MiB
# cuda-bindings ------------------------------ 894.05 KiB/11.59 MiB
# numpy      ------------------------------ 884.81 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 942.05 KiB/37.44 MiB
# bitsandbytes ------------------------------ 876.80 KiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 856.56 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 883.39 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 126.83 KiB/132.66 MiB
# triton     ------------------------------ 955.53 KiB/179.55 MiB
# nvidia-cufft-cu12 ------------------------------ 920.56 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 909.96 KiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 910.83 KiB/274.86 MiB
# ⠸ Preparing packages... (15/40)
# fsspec     ------------------------------ 190.92 KiB/197.11 KiB
# accelerate ------------------------------ 192.71 KiB/372.01 KiB
# huggingface-hub ------------------------------ 334.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 776.56 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 584.56 KiB/932.39 KiB
# setuptools ------------------------------ 174.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 942.05 KiB/1.14 MiB
# networkx   ------------------------------ 198.75 KiB/1.97 MiB
# hf-xet     ------------------------------ 904.56 KiB/3.17 MiB
# sympy      ------------------------------ 112.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 948.81 KiB/9.77 MiB
# cuda-bindings ------------------------------ 941.95 KiB/11.59 MiB
# numpy      ------------------------------ 932.81 KiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 975.59 KiB/37.44 MiB
# bitsandbytes ------------------------------ 924.80 KiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 904.56 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 920.56 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 909.98 KiB/132.66 MiB
# triton     ------------------------------ 1003.53 KiB/179.55 MiB
# nvidia-cufft-cu12 ------------------------------ 963.56 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 965.36 KiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 958.83 KiB/274.86 MiB
# ⠸ Preparing packages... (15/40)
# fsspec     ------------------------------ 190.92 KiB/197.11 KiB
# accelerate ------------------------------ 222.89 KiB/372.01 KiB
# huggingface-hub ------------------------------ 350.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 788.94 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 604.02 KiB/932.39 KiB
# setuptools ------------------------------ 174.85 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 1.12 MiB/1.14 MiB
# networkx   ------------------------------ 230.75 KiB/1.97 MiB
# hf-xet     ------------------------------ 1.04 MiB/3.17 MiB
# sympy      ------------------------------ 128.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.10 MiB/9.77 MiB
# cuda-bindings ------------------------------ 990.05 KiB/11.59 MiB
# numpy      ------------------------------ 1.05 MiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.09 MiB/37.44 MiB
# bitsandbytes ------------------------------ 1.06 MiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 1.08 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.10 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 1.04 MiB/132.66 MiB
# triton     ------------------------------ 1.17 MiB/179.55 MiB
# nvidia-cufft-cu12 ------------------------------ 1.10 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.08 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.12 MiB/274.86 MiB
# ⠸ Preparing packages... (15/40)
# accelerate ------------------------------ 222.89 KiB/372.01 KiB
# huggingface-hub ------------------------------ 350.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 788.94 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 604.02 KiB/932.39 KiB
# setuptools ------------------------------ 190.75 KiB/1.01 MiB
# nvidia-cufile-cu12 ------------------------------ 1.14 MiB/1.14 MiB
# networkx   ------------------------------ 235.02 KiB/1.97 MiB
# hf-xet     ------------------------------ 1.14 MiB/3.17 MiB
# sympy      ------------------------------ 128.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.16 MiB/9.77 MiB
# cuda-bindings ------------------------------ 1.09 MiB/11.59 MiB
# numpy      ------------------------------ 1.14 MiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.19 MiB/37.44 MiB
# bitsandbytes ------------------------------ 1.17 MiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 1.14 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.14 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 1.17 MiB/132.66 MiB
# triton     ------------------------------ 1.23 MiB/179.55 MiB
# nvidia-cufft-cu12 ------------------------------ 1.21 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.17 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.17 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.14 MiB/307.42 MiB
# ⠸ Preparing packages... (15/40)
# accelerate ------------------------------ 238.89 KiB/372.01 KiB
# huggingface-hub ------------------------------ 350.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 788.94 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 620.02 KiB/932.39 KiB
# setuptools ------------------------------ 190.75 KiB/1.01 MiB
# networkx   ------------------------------ 251.02 KiB/1.97 MiB
# hf-xet     ------------------------------ 1.22 MiB/3.17 MiB
# sympy      ------------------------------ 144.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.23 MiB/9.77 MiB
# cuda-bindings ------------------------------ 1.26 MiB/11.59 MiB
# numpy      ------------------------------ 1.24 MiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.26 MiB/37.44 MiB
# bitsandbytes ------------------------------ 1.25 MiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 1.24 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.24 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 1.26 MiB/132.66 MiB
# triton     ------------------------------ 1.31 MiB/179.55 MiB
# nvidia-cufft-cu12 ------------------------------ 1.30 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.26 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.25 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.22 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 1.24 MiB/566.81 MiB
# ⠸ Preparing packages... (15/40)
# accelerate ------------------------------ 238.89 KiB/372.01 KiB
# huggingface-hub ------------------------------ 350.88 KiB/524.15 KiB
# pyyaml     ------------------------------ 788.94 KiB/788.94 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 620.02 KiB/932.39 KiB
# setuptools ------------------------------ 190.75 KiB/1.01 MiB
# networkx   ------------------------------ 251.02 KiB/1.97 MiB
# hf-xet     ------------------------------ 1.22 MiB/3.17 MiB
# sympy      ------------------------------ 144.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.23 MiB/9.77 MiB
# cuda-bindings ------------------------------ 1.28 MiB/11.59 MiB
# numpy      ------------------------------ 1.24 MiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.26 MiB/37.44 MiB
# bitsandbytes ------------------------------ 1.25 MiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 1.24 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.24 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 1.26 MiB/132.66 MiB
# triton     ------------------------------ 1.31 MiB/179.55 MiB
# nvidia-cufft-cu12 ------------------------------ 1.30 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.26 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.25 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.22 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 1.24 MiB/566.81 MiB
# ⠸ Preparing packages... (15/40)
# accelerate ------------------------------ 238.89 KiB/372.01 KiB
# huggingface-hub ------------------------------ 350.88 KiB/524.15 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 636.02 KiB/932.39 KiB
# setuptools ------------------------------ 190.75 KiB/1.01 MiB
# networkx   ------------------------------ 251.02 KiB/1.97 MiB
# hf-xet     ------------------------------ 1.25 MiB/3.17 MiB
# sympy      ------------------------------ 144.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.26 MiB/9.77 MiB
# cuda-bindings ------------------------------ 1.33 MiB/11.59 MiB
# numpy      ------------------------------ 1.28 MiB/15.85 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.33 MiB/37.44 MiB
# bitsandbytes ------------------------------ 1.27 MiB/56.32 MiB
# nvidia-curand-cu12 ------------------------------ 1.30 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.30 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 1.31 MiB/132.66 MiB
# triton     ------------------------------ 1.35 MiB/179.55 MiB
# nvidia-cufft-cu12 ------------------------------ 1.35 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.31 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.29 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.26 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 1.27 MiB/566.81 MiB
# ⠸ Preparing packages... (15/40)
# accelerate ------------------------------ 302.89 KiB/372.01 KiB
# huggingface-hub ------------------------------ 360.72 KiB/524.15 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 648.56 KiB/932.39 KiB
# setuptools ------------------------------ 206.75 KiB/1.01 MiB
# networkx   ------------------------------ 262.75 KiB/1.97 MiB
# hf-xet     ------------------------------ 1.39 MiB/3.17 MiB
# sympy      ------------------------------ 176.00 KiB/6.01 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.38 MiB/9.77 MiB
# ...
# ⠸ Preparing packages... (37/40)
# nvidia-nccl-cu12 ------------------------------ 295.37 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 302.17 MiB/566.81 MiB
# ⠸ Preparing packages... (37/40)
# nvidia-nccl-cu12 ------------------------------ 298.02 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 303.92 MiB/566.81 MiB
# ⠼ Preparing packages... (37/40)
# nvidia-nccl-cu12 ------------------------------ 299.14 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 307.31 MiB/566.81 MiB
# ⠼ Preparing packages... (37/40)
# nvidia-nccl-cu12 ------------------------------ 301.91 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 309.00 MiB/566.81 MiB
# ⠼ Preparing packages... (37/40)
# nvidia-nccl-cu12 ------------------------------ 302.91 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 313.02 MiB/566.81 MiB
# ⠼ Preparing packages... (37/40)
# nvidia-nccl-cu12 ------------------------------ 302.91 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 316.80 MiB/566.81 MiB
# ⠴ Preparing packages... (37/40)
# nvidia-nccl-cu12 ------------------------------ 305.91 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 318.96 MiB/566.81 MiB
# ⠴ Preparing packages... (37/40)
# nvidia-cublas-cu12 ------------------------------ 320.96 MiB/566.81 MiB
# ⠴ Preparing packages... (37/40)
# nvidia-cublas-cu12 ------------------------------ 321.67 MiB/566.81 MiB
# ⠴ Preparing packages... (37/40)
# nvidia-cublas-cu12 ------------------------------ 323.49 MiB/566.81 MiB
# ⠴ Preparing packages... (37/40)
# nvidia-cublas-cu12 ------------------------------ 328.14 MiB/566.81 MiB
# ⠦ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 332.49 MiB/566.81 MiB
# ⠦ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 333.89 MiB/566.81 MiB
# ⠦ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 333.89 MiB/566.81 MiB
# ⠦ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 333.89 MiB/566.81 MiB
# ⠧ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 333.89 MiB/566.81 MiB
# ⠧ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 334.17 MiB/566.81 MiB
# ⠧ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 338.68 MiB/566.81 MiB
# ⠧ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 343.78 MiB/566.81 MiB
# ⠇ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 347.02 MiB/566.81 MiB
# ⠇ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 351.02 MiB/566.81 MiB
# ⠇ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 357.02 MiB/566.81 MiB
# ⠇ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 361.02 MiB/566.81 MiB
# ⠋ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 366.22 MiB/566.81 MiB
# ⠋ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 373.02 MiB/566.81 MiB
# ⠋ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 381.02 MiB/566.81 MiB
# ⠋ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 387.78 MiB/566.81 MiB
# ⠙ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 388.87 MiB/566.81 MiB
# ⠙ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 392.02 MiB/566.81 MiB
# ⠙ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 400.02 MiB/566.81 MiB
# ⠙ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 408.26 MiB/566.81 MiB
# ⠹ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 414.16 MiB/566.81 MiB
# ⠹ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 421.32 MiB/566.81 MiB
# ⠹ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 428.06 MiB/566.81 MiB
# ⠹ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 436.91 MiB/566.81 MiB
# ⠸ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 443.03 MiB/566.81 MiB
# ⠸ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 450.02 MiB/566.81 MiB
# ⠸ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 457.58 MiB/566.81 MiB
# ⠸ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 464.02 MiB/566.81 MiB
# ⠼ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 468.02 MiB/566.81 MiB
# ⠼ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 470.90 MiB/566.81 MiB
# ⠼ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 471.02 MiB/566.81 MiB
# ⠼ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 475.38 MiB/566.81 MiB
# ⠴ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 478.02 MiB/566.81 MiB
# ⠴ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 482.02 MiB/566.81 MiB
# ⠴ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 487.29 MiB/566.81 MiB
# ⠴ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 495.52 MiB/566.81 MiB
# ⠦ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 504.60 MiB/566.81 MiB
# ⠦ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 509.42 MiB/566.81 MiB
# ⠦ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 509.42 MiB/566.81 MiB
# ⠦ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 511.00 MiB/566.81 MiB
# ⠧ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 519.18 MiB/566.81 MiB
# ⠧ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 520.02 MiB/566.81 MiB
# ⠧ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 527.23 MiB/566.81 MiB
# ⠧ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 533.29 MiB/566.81 MiB
# ⠇ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 542.70 MiB/566.81 MiB
# ⠇ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 550.69 MiB/566.81 MiB
# ⠇ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 556.50 MiB/566.81 MiB
# ⠇ Preparing packages... (38/40)
# nvidia-cublas-cu12 ------------------------------ 559.02 MiB/566.81 MiB
# ⠋ Preparing packages... (38/40)
# ⠋ Preparing packages... (38/40)
# ⠋ Preparing packages... (38/40)
# ⠋ Preparing packages... (38/40)
# ⠋ Preparing packages... (38/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠸ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠼ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠴ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠦ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠧ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠇ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠋ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠙ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# ⠹ Preparing packages... (39/40)
# Prepared 40 packages in 36.47s
# Uninstalled 36 packages in 1.21s
# Installed 40 packages in 759ms
#  - accelerate==1.10.1
#  + accelerate==1.12.0
#  - anyio==4.10.0
#  + anyio==4.12.1
#  + bitsandbytes==0.49.1
#  - certifi==2024.8.30
#  + certifi==2026.1.4
#  - click==8.2.1
#  + click==8.3.1
#  + cuda-bindings==12.9.4
#  + cuda-pathfinder==1.3.3
#  - filelock==3.13.1
#  + filelock==3.20.3
#  - fsspec==2024.6.1
#  + fsspec==2026.1.0
#  - hf-xet==1.1.9
#  + hf-xet==1.2.0
#  - huggingface-hub==0.34.4
#  + huggingface-hub==1.3.7
#  - idna==3.10
#  + idna==3.11
#  - jinja2==3.1.4
#  + jinja2==3.1.6
#  - markupsafe==2.1.5
#  + markupsafe==3.0.3
#  - networkx==3.3
#  + networkx==3.6.1
#  - numpy==2.1.2
#  + numpy==2.4.2
#  - nvidia-cublas-cu12==12.9.1.4
#  + nvidia-cublas-cu12==12.8.4.1
#  - nvidia-cuda-cupti-cu12==12.9.79
#  + nvidia-cuda-cupti-cu12==12.8.90
#  - nvidia-cuda-nvrtc-cu12==12.9.86
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  - nvidia-cuda-runtime-cu12==12.9.79
#  + nvidia-cuda-runtime-cu12==12.8.90
#  - nvidia-cufft-cu12==11.4.1.4
#  + nvidia-cufft-cu12==11.3.3.83
#  - nvidia-cufile-cu12==1.14.1.1
#  + nvidia-cufile-cu12==1.13.1.3
#  - nvidia-curand-cu12==10.3.10.19
#  + nvidia-curand-cu12==10.3.9.90
#  - nvidia-cusolver-cu12==11.7.5.82
#  + nvidia-cusolver-cu12==11.7.3.90
#  - nvidia-cusparse-cu12==12.5.10.65
#  + nvidia-cusparse-cu12==12.5.8.93
#  - nvidia-nccl-cu12==2.27.3
#  + nvidia-nccl-cu12==2.27.5
#  - nvidia-nvjitlink-cu12==12.9.86
#  + nvidia-nvjitlink-cu12==12.8.93
#  - nvidia-nvshmem-cu12==3.3.24
#  + nvidia-nvshmem-cu12==3.4.5
#  - nvidia-nvtx-cu12==12.9.79
#  + nvidia-nvtx-cu12==12.8.90
#  - packaging==25.0
#  + packaging==26.0
#  - psutil==7.0.0
#  + psutil==7.2.2
#  - pyyaml==6.0.2
#  + pyyaml==6.0.3
#  - safetensors==0.6.2
#  + safetensors==0.7.0
#  - setuptools==70.2.0
#  + setuptools==80.10.2
#  - sympy==1.13.3
#  + sympy==1.14.0
#  - torch==2.8.0+cu129
#  + torch==2.10.0
#  - tqdm==4.67.1
#  + tqdm==4.67.3
#  - triton==3.4.0
#  + triton==3.6.0
#  + typer-slim==0.21.1
#  - typing-extensions==4.12.2
#  + typing-extensions==4.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %uv pip install transformers==5.0.0
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Resolved 22 packages in 109ms
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 16.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 16.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 32.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 32.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 32.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 32.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 32.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 32.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 32.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 48.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 48.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 48.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 48.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 64.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 80.00 KiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# tokenizers ------------------------------ 2.08 MiB/3.12 MiB
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠹ Preparing packages... (1/2)
# ⠹ Preparing packages... (1/2)
# ⠹ Preparing packages... (1/2)
# ⠹ Preparing packages... (1/2)
# ⠸ Preparing packages... (1/2)
# Prepared 2 packages in 455ms
# Uninstalled 2 packages in 361ms
# Installed 2 packages in 160ms
#  - tokenizers==0.22.0
#  + tokenizers==0.22.2
#  - transformers==4.56.0
#  + transformers==5.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import transformers
print(transformers.__version__)
# Out:
# 5.0.0

# %%
# %uv pip install --upgrade torch torchvision
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Resolved 31 packages in 77ms
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------     0 B/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 16.00 KiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 32.00 KiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 32.00 KiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 32.00 KiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 32.00 KiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 32.00 KiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 32.00 KiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 32.00 KiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 32.00 KiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 32.00 KiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 32.00 KiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 48.00 KiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 2.27 MiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# pillow     ------------------------------ 5.60 MiB/6.72 MiB
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# Prepared 2 packages in 224ms
# Uninstalled 2 packages in 27ms
# Installed 2 packages in 67ms
#  - pillow==11.0.0
#  + pillow==12.1.0
#  - torchvision==0.23.0+cu129
#  + torchvision==0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from tqdm import tqdm

# Cleaning khusus
def normalize_caption_post(text):
    if pd.isna(text):
        return None
    text = str(text).lower()
    text = re.sub(r"[—–−]+", "-", text)          
    text = re.sub(r"#\w+", "", text)              
    text = re.sub(r"http\S+|www\S+", "", text)    
    text = re.sub(r"[\U00010000-\U0010FFFF]", "", text)  
    return text.strip()

def clean_caption_text_from_row(row):
    caption = normalize_caption_post(row["caption"])
    if caption is None:
        return None
    
    nama_tempat = str(row.get("Nama Tempat", "")).lower().strip()
    alamat     = str(row.get("Alamat", "")).lower().strip()
    
    lines = [l.strip() for l in caption.split("\n") if l.strip()]
    cleaned_lines = []
    
    for line in lines:
        low = line.lower()
        if nama_tempat and nama_tempat in low:
            continue
        if alamat and alamat in low:
            continue
        
        
        line = re.sub(r"@\w+", "", line)          
        line = re.sub(r"#\w+", "", line)           
        line = re.sub(r"[^a-z\s.,!?]", " ", line)  
        line = re.sub(r"\s+", " ", line).strip()
        
        if line:
            cleaned_lines.append(line)
    
    return " ".join(cleaned_lines) if cleaned_lines else None

data = pd.read_csv("/root/lda_categorized_posts.csv")


print("Kolom yang tersedia:", data.columns.tolist())
# Out:
# Kolom yang tersedia: ['caption', 'Nama Tempat', 'Alamat', 'Jam Operasional', 'Kota', 'Akun Instagram', 'Jam Buka', 'Jam Tutup', 'Is 24H', 'Is Overnight', 'Kategori Tempat', 'Kategori Multilabel List', 'Kategori Multilabel']

# %%
data
# Out:
#                                                caption  \
# 0    Seriussn waktu itu pas lewat kirain gedung nik...
# 1    Seriusan coffee shop baru 24 jam dari Bandung ...
# 2    Baru di Jogja - Artisan bakery & coffee esteti...
# 3    Cold ‘N Brew baru aja buka cabangnya di Maliob...
# 4    Baru lagi di Jogja! Coffee & dining artistik a...
# ..                                                 ...
# 304  Lunaria, coffee and eatery estetik baru di Ged...
# 305  Kolokial Coffee, coffee shop bertema medieval ...
# 306  Merindu bersama di Ruang Rindu Coffee\n\nCoffe...
# 307  Kastem Space Gantara, penyegaran coffee shop d...
# 308  Beberapa hari kemarin kami iseng pengen ngopi ...
#
#                        Nama Tempat  \
# 0    Lyon’s Cafe & Coworking Space
# 1                  Beri Kopi Jogja
# 2        Elder On The Table - EOTB
# 3           Seperti cabang lainnya
# 4              Waktu Luang De Loji
# ..                             ...
# 304                 Lunaria Coffee
# 305                Kolokial Coffee
# 306             Ruang Rindu Coffee
# 307         Kasteman Space Gantara
# 308               Inspira Roasters
#
#                                                 Alamat Jam Operasional  \
# 0    Jl. Nyi Tjondrolukito No 82, Kutu Dukuh, Sindu...          24 Jam
# 1               Dero, Condongcatur, Sleman, Yogyakarta          24 Jam
# 2                      Jl. Kranggan, Jetis, Yogyakarta   07:00 - 22:00
# 3                              Jl. Mataram, Yogyakarta          24 Jam
# 4    Jl. Panembahan Senopati, Prawirodirjan, Kec. G...   10:00 - 22:00
# ..                                                 ...             ...
# 304          Jl. Gedongkiwo No.29 (Pojok Beteng Kulon)   08:00 - 22:00
# 305  Jl. Affandi No.30, Condongcatur, Depok, Kabupa...     09:00-22.00
# 306  Jl. Perumnas, Kledokan, Caturtunggal, Depok, S...   08:00 - 01:00
# 307  Jl. Lowanu, Sorosutan, Umbulharjo, Kota Yogyak...   10:00 - 24.00
# 308  Gaia Cosmo Hotel, Jl. Ipda Tut Harsono, Muja M...          24 Jam
#
#            Kota                       Akun Instagram Jam Buka Jam Tutup  \
# 0        Sleman                        @lyonscafe.co    00:00     23:59
# 1        Sleman                      @berikopi.jogja    00:00     23:59
# 2    Yogyakarta  @elder.onthetable, @elderpatisserie    07:00     22:00
# 3    Yogyakarta                           @coldnbrew    00:00     23:59
# 4    Yogyakarta                   @waktuluang.deloji    10:00     22:00
# ..          ...                                  ...      ...       ...
# 304     Lainnya                       @lunariacoffee    08:00     22:00
# 305      Sleman                   @kolokial.coffeeyk    09:00     22:00
# 306      Sleman                      @kopiruangrindu    08:00     01:00
# 307  Yogyakarta                 @kastemspace_gantara    10:00     23:59
# 308  Yogyakarta                     @inspiraroasters    00:00     23:59
#
#      Is 24H  Is Overnight Kategori Tempat          Kategori Multilabel List  \
# 0      True         False    Ngopi Santai    ['Ngopi Santai', 'WFC Nyaman']
# 1      True         False    Ngopi Santai  ['Ngopi Santai', 'Area Lengkap']
# 2     False         False    Ngopi Santai                  ['Ngopi Santai']
# 3      True         False    Area Lengkap                  ['Area Lengkap']
# 4     False         False    Ngopi Santai                  ['Ngopi Santai']
# ..      ...           ...             ...                               ...
# 304   False         False      WFC Nyaman   ['Menu Variatif', 'WFC Nyaman']
# 305   False         False   Menu Variatif   ['Menu Variatif', 'WFC Nyaman']
# 306   False          True      WFC Nyaman   ['Menu Variatif', 'WFC Nyaman']
# 307   False         False   Menu Variatif                 ['Menu Variatif']
# 308    True         False      WFC Nyaman                    ['WFC Nyaman']
#
#             Kategori Multilabel
# 0      Ngopi Santai, WFC Nyaman
# 1    Ngopi Santai, Area Lengkap
# 2                  Ngopi Santai
# 3                  Area Lengkap
# 4                  Ngopi Santai
# ..                          ...
# 304   Menu Variatif, WFC Nyaman
# 305   Menu Variatif, WFC Nyaman
# 306   Menu Variatif, WFC Nyaman
# 307               Menu Variatif
# 308                  WFC Nyaman
#
# [309 rows x 13 columns]

# %%
data['normalized_caption'] = data['caption'].apply(normalize_caption_post)

data['clean_caption'] = data.apply(clean_caption_text_from_row, axis=1)

data_clean = data[data['clean_caption'].notna() & (data['clean_caption'].str.strip() != '')].copy()
print(f"Jumlah data setelah cleaning: {len(data_clean)} (dari total {len(data)})")

model_id = "GoToCompany/gemma2-9b-cpt-sahabatai-v1-instruct"

quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    quantization_config=quant_config
)


def build_prompt(caption):
    return f"""\
Tugas:
Ekstrak informasi dari caption Instagram tentang coffee shop.

Aturan:
- Gunakan hanya informasi yang tertulis di caption.
- Jangan menambahkan informasi di luar caption.

Output:
1) Deskripsi
   - Apa yang dibahas (makanan, minuman, tempat, atau aktivitas di coffee shop).
   - Tulis jam operasionalnya.
   - Maksimal 1 kalimat saja.

2) Opini
   - Opini tentang makanan, minuman, tempat, atau suasana.
   - Opini boleh eksplisit atau implisit.
   - Jika tidak ada opini tersebut → "Netral".

Format wajib:

Deskripsi: <isi>
Opini: <isi>

Caption:
"{caption}"
"""

def extract_info(caption, max_new_tokens=150):
    prompt = build_prompt(caption)
    messages = [{"role": "user", "content": prompt}]
    
    encodings = tokenizer.apply_chat_template(
        messages,
        tokenize=True,
        add_generation_prompt=True,
        return_tensors="pt"
    )
    
    input_ids = encodings.input_ids.to(model.device)
    attention_mask = encodings.attention_mask.to(model.device)
    
    with torch.no_grad():
        outputs = model.generate(
            input_ids,
            attention_mask=attention_mask,
            max_new_tokens=max_new_tokens,
            do_sample=False,  
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id
        )
    
    return tokenizer.decode(outputs[0], skip_special_tokens=True)


def parse_llm_output(text):
    desc = "Tidak tersedia"
    opin = "Netral"
    
    if "Deskripsi:" in text:
        after_desc = text.split("Deskripsi:")[-1].strip()
        if "Opini:" in after_desc:
            d_part, o_part = after_desc.split("Opini:", 1)
            desc = d_part.strip()
            opin = o_part.strip()
        else:
            desc = after_desc.strip()
    
    desc = re.sub(r'\s+', ' ', desc).strip()
    opin = re.sub(r'\s+', ' ', opin).strip()
    
    if not desc or len(desc) < 5:
        desc = "Tidak tersedia"
    if not opin or len(opin) < 3:
        opin = "Netral"
    
    return desc, opin


deskripsi_list = []
opini_list = []

for caption in tqdm(data_clean['clean_caption'], desc="Ekstraksi dengan LLM"):
    if not caption.strip():
        deskripsi_list.append("Tidak tersedia")
        opini_list.append("Netral")
        continue
    
    raw = extract_info(caption)
    d, o = parse_llm_output(raw)
    deskripsi_list.append(d)
    opini_list.append(o)

data_clean['deskripsi'] = deskripsi_list
data_clean['opini'] = opini_list


data_clean.to_csv("/root/extracted_data_sahabatai(gemma).csv", index=False)
# Out:
# Jumlah data setelah cleaning: 309 (dari total 309)
# Loading weights:   0%|          | 0/464 [00:00<?, ?it/s]
# Ekstraksi dengan LLM: 100%|██████████████████████████████████████████████████| 309/309 [37:31<00:00,  7.29s/it]

# %%
data_clean
# Out:
#                                                caption  \
# 0    Seriussn waktu itu pas lewat kirain gedung nik...
# 1    Seriusan coffee shop baru 24 jam dari Bandung ...
# 2    Baru di Jogja - Artisan bakery & coffee esteti...
# 3    Cold ‘N Brew baru aja buka cabangnya di Maliob...
# 4    Baru lagi di Jogja! Coffee & dining artistik a...
# ..                                                 ...
# 304  Lunaria, coffee and eatery estetik baru di Ged...
# 305  Kolokial Coffee, coffee shop bertema medieval ...
# 306  Merindu bersama di Ruang Rindu Coffee\n\nCoffe...
# 307  Kastem Space Gantara, penyegaran coffee shop d...
# 308  Beberapa hari kemarin kami iseng pengen ngopi ...
#
#                        Nama Tempat  \
# 0    Lyon’s Cafe & Coworking Space
# 1                  Beri Kopi Jogja
# 2        Elder On The Table - EOTB
# 3           Seperti cabang lainnya
# 4              Waktu Luang De Loji
# ..                             ...
# 304                 Lunaria Coffee
# 305                Kolokial Coffee
# 306             Ruang Rindu Coffee
# 307         Kasteman Space Gantara
# 308               Inspira Roasters
#
#                                                 Alamat Jam Operasional  \
# 0    Jl. Nyi Tjondrolukito No 82, Kutu Dukuh, Sindu...          24 Jam
# 1               Dero, Condongcatur, Sleman, Yogyakarta          24 Jam
# 2                      Jl. Kranggan, Jetis, Yogyakarta   07:00 - 22:00
# 3                              Jl. Mataram, Yogyakarta          24 Jam
# 4    Jl. Panembahan Senopati, Prawirodirjan, Kec. G...   10:00 - 22:00
# ..                                                 ...             ...
# 304          Jl. Gedongkiwo No.29 (Pojok Beteng Kulon)   08:00 - 22:00
# 305  Jl. Affandi No.30, Condongcatur, Depok, Kabupa...     09:00-22.00
# 306  Jl. Perumnas, Kledokan, Caturtunggal, Depok, S...   08:00 - 01:00
# 307  Jl. Lowanu, Sorosutan, Umbulharjo, Kota Yogyak...   10:00 - 24.00
# 308  Gaia Cosmo Hotel, Jl. Ipda Tut Harsono, Muja M...          24 Jam
#
#            Kota                       Akun Instagram Jam Buka Jam Tutup  \
# 0        Sleman                        @lyonscafe.co    00:00     23:59
# 1        Sleman                      @berikopi.jogja    00:00     23:59
# 2    Yogyakarta  @elder.onthetable, @elderpatisserie    07:00     22:00
# 3    Yogyakarta                           @coldnbrew    00:00     23:59
# 4    Yogyakarta                   @waktuluang.deloji    10:00     22:00
# ..          ...                                  ...      ...       ...
# 304     Lainnya                       @lunariacoffee    08:00     22:00
# 305      Sleman                   @kolokial.coffeeyk    09:00     22:00
# 306      Sleman                      @kopiruangrindu    08:00     01:00
# 307  Yogyakarta                 @kastemspace_gantara    10:00     23:59
# 308  Yogyakarta                     @inspiraroasters    00:00     23:59
#
#      Is 24H  Is Overnight Kategori Tempat          Kategori Multilabel List  \
# 0      True         False    Ngopi Santai    ['Ngopi Santai', 'WFC Nyaman']
# 1      True         False    Ngopi Santai  ['Ngopi Santai', 'Area Lengkap']
# 2     False         False    Ngopi Santai                  ['Ngopi Santai']
# 3      True         False    Area Lengkap                  ['Area Lengkap']
# 4     False         False    Ngopi Santai                  ['Ngopi Santai']
# ..      ...           ...             ...                               ...
# 304   False         False      WFC Nyaman   ['Menu Variatif', 'WFC Nyaman']
# 305   False         False   Menu Variatif   ['Menu Variatif', 'WFC Nyaman']
# 306   False          True      WFC Nyaman   ['Menu Variatif', 'WFC Nyaman']
# 307   False         False   Menu Variatif                 ['Menu Variatif']
# 308    True         False      WFC Nyaman                    ['WFC Nyaman']
#
#             Kategori Multilabel  \
# 0      Ngopi Santai, WFC Nyaman
# 1    Ngopi Santai, Area Lengkap
# 2                  Ngopi Santai
# 3                  Area Lengkap
# 4                  Ngopi Santai
# ..                          ...
# 304   Menu Variatif, WFC Nyaman
# 305   Menu Variatif, WFC Nyaman
# 306   Menu Variatif, WFC Nyaman
# 307               Menu Variatif
# 308                  WFC Nyaman
#
#                                     normalized_caption  \
# 0    seriussn waktu itu pas lewat kirain gedung nik...
# 1    seriusan coffee shop baru 24 jam dari bandung ...
# 2    baru di jogja - artisan bakery & coffee esteti...
# 3    cold ‘n brew baru aja buka cabangnya di maliob...
# 4    baru lagi di jogja! coffee & dining artistik a...
# ..                                                 ...
# 304  lunaria, coffee and eatery estetik baru di ged...
# 305  kolokial coffee, coffee shop bertema medieval ...
# 306  merindu bersama di ruang rindu coffee\n\ncoffe...
# 307  kastem space gantara, penyegaran coffee shop d...
# 308  beberapa hari kemarin kami iseng pengen ngopi ...
#
#                                          clean_caption  \
# 0    seriussn waktu itu pas lewat kirain gedung nik...
# 1    seriusan coffee shop baru jam dari bandung ini...
# 2    baru di jogja artisan bakery coffee estetik lu...
# 3    cold n brew baru aja buka cabangnya di maliobo...
# 4    baru lagi di jogja! coffee dining artistik aes...
# ..                                                 ...
# 304  lunaria, coffee and eatery estetik baru di ged...
# 305  tempat ini sudah membuat kami penasaran sejak ...
# 306  coffee shop yang letaknya di jalan perumnas in...
# 307  kastem space gantara, penyegaran coffee shop d...
# 308  . . kalau kamu pengen sekali kali ngopi di sin...
#
#                                              deskripsi  \
# 0    Coffee shop luas dengan area parkir yang luas,...
# 1    Coffee shop baru di Bandung dengan menu yang e...
# 2    .onthetable adalah coffee shop yang baru buka ...
# 3    Cold N Brew baru buka cabang di Malioboro, buk...
# 4    Coffee shop bernama .deloji di Jogja, dekat ti...
# ..                                                 ...
# 304  Lunaria, coffee and eatery estetik baru di Ged...
# 305            Tempat nongkrong baru di pinggir jalan.
# 306  Coffee shop dengan konsep coffee bar bertema g...
# 307  Kastem Space Gantara, coffee shop di selatan J...
# 308  Coffee shop ini memiliki menu beragam mulai da...
#
#                                                  opini
# 0    Positif (menguji tempat duduk dan menu yang te...
# 1                                Tempat dan menu enak.
# 2    Tempat ini memiliki suasana yang nyaman dan me...
# 3                                              Netral.
# 4    Positif, penulis memuji konsep, menu, dan pela...
# ..                                                 ...
# 304  Suasana kondusif dan tenang, didukung oleh ker...
# 305                                            Netral.
# 306  Suasana coffee shop ini santai dan nostalgic, ...
# 307  Positif. Penulis menyukai suasana dan menu di ...
# 308                                             Netral
#
# [309 rows x 17 columns]

# %%
# %uv pip install openpyxl
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Resolved 2 packages in 33ms
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# et-xmlfile ------------------------------ 14.89 KiB/17.64 KiB
# ⠙ Preparing packages... (0/2)
# et-xmlfile ------------------------------ 14.89 KiB/17.64 KiB
# ⠙ Preparing packages... (0/2)
# et-xmlfile ------------------------------ 17.64 KiB/17.64 KiB
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# Prepared 2 packages in 31ms
# Installed 2 packages in 60ms
#  + et-xmlfile==2.0.0
#  + openpyxl==3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
data_clean.to_excel("/root/extracted_data_sahabatai.xlsx", index=False)
data_clean.to_csv("/root/extracted_data_sahabatai.csv", index=False)

# %%
data_filtered = data_clean[['clean_caption', 'opini', 'deskripsi']]

data_filtered.to_csv("extracted_data_sahabatai_1.csv", index=False)
