# %%
import pandas as pd
from sqlalchemy import create_engine
import re
from datetime import time
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# # Instagram Coffee Shop (@referensikopi) Data Processing
#
# ## 1. Overview
#
# **Tujuan:** Mengubah caption tidak terstruktur menjadi data terstruktur yang siap untuk analisis, beserta ekstraksi kategori menu dan fungsi.
#
# **Output:**
# - `preprocessed_posts.csv` - Data terstruktur siap analisis
# - `preprocessed_posts.xlsx` - Data dalam format Excel
# - `preprocessed_posts` - Tabel di database PostgreSQL
#
# ---
#
# ## 2. Alur Proses
#
# ```
# PostgreSQL (insta_kuliner)
#     ↓
# Extract (SQL Query)
#     ↓
# Transform (Parsing & Normalisasi)
#     ├─ Ekstraksi informasi dari caption
#     ├─ Parsing jam operasional
#     ├─ Normalisasi teks caption
#     ├─ Ekstraksi kota dari alamat
#     ├─ Ekstraksi kategori menu dan fungsi
#     └─ Pembersihan data (dropna, drop_duplicates, hapus emoji)
#     ↓
# Load (Save Data)
#     ├─ preprocessed_posts.csv
#     ├─ preprocessed_posts.xlsx
#     └─ Table: preprocessed_posts (PostgreSQL)
# ```
#
# ---
#
# ## 3. Tools yang Digunakan
#
# | Tahap | Tools | Fungsi |
# |-------|-------|--------|
# | **Extract** | PostgreSQL, SQLAlchemy, pandas | Koneksi database & query data |
# | **Transform** | Python, pandas, regex | Parsing, ekstraksi, normalisasi data |
# | **Load** | pandas, SQLAlchemy | Export CSV, Excel, dan simpan ke database |

# %% [markdown]
# ---
#
# ## 4. Extract (Pengambilan Data)
#
# ### 4.1 Sumber Data
#
# | Item | Keterangan |
# |------|-----------|
# | **Akun Instagram** | `@referensikopi` |
# | **Database** | PostgreSQL |
# | **Nama Database** | `insta_kuliner` |
# | **Tabel** | `posts` |
# | **Jumlah Data** | 558 postingan |

# %%
# koneksi ke database
engine = create_engine('postgresql://postgres:solosolo29@localhost/insta_kuliner')

# query berdasarkan username
posts = pd.read_sql_query(
    "SELECT * FROM posts WHERE username = 'referensikopi' ORDER BY posted_at DESC",
    engine
)

print(f"\nJumlah Postingan: {len(posts)}")
posts
# Out:
# Jumlah Postingan: 558
#       id              post_id    shortcode  \
# 0    341  3812780142117828210  DTpt1aZmLZy
# 1    342  3811279003139877132  DTkYg9yDqkM
# 2    343  3809886712190503101  DTfb8dymIi9
# 3    344  3809040153340852565  DTcbdabFLlV
# 4    345  3808363008612680972  DTaBfqQGMUM
# ..   ...                  ...          ...
# 553  894  1920359859627240624  BqmfR4qACyw
# 554  895  1828346068820935699  BlflxAGjcQT
# 555  896  1745008286467829823  Bg3g8qFBzA_
# 556  897  1731205496473637852  BgGejoKg9Pc
# 557  898  1703669753853650099  Bekpp1dBiSz
#
#                                      post_url       username  \
# 0    https://www.instagram.com/p/DTpt1aZmLZy/  referensikopi
# 1    https://www.instagram.com/p/DTkYg9yDqkM/  referensikopi
# 2    https://www.instagram.com/p/DTfb8dymIi9/  referensikopi
# 3    https://www.instagram.com/p/DTcbdabFLlV/  referensikopi
# 4    https://www.instagram.com/p/DTaBfqQGMUM/  referensikopi
# ..                                        ...            ...
# 553  https://www.instagram.com/p/BqmfR4qACyw/  referensikopi
# 554  https://www.instagram.com/p/BlflxAGjcQT/  referensikopi
# 555  https://www.instagram.com/p/Bg3g8qFBzA_/  referensikopi
# 556  https://www.instagram.com/p/BgGejoKg9Pc/  referensikopi
# 557  https://www.instagram.com/p/Bekpp1dBiSz/  referensikopi
#
#                                                caption  likes_count  \
# 0    Seriussn waktu itu pas lewat kirain gedung nik...          189
# 1    Seriusan coffee shop baru 24 jam dari Bandung ...           81
# 2    Baru di Jogja - Artisan bakery & coffee esteti...          189
# 3    Cold ‘N Brew baru aja buka cabangnya di Maliob...          152
# 4    Baru lagi di Jogja! Coffee & dining artistik a...          595
# ..                                                 ...          ...
# 553  Kalau kamu lagi pengen ngopi enak tempat ini b...          304
# 554  Ngopi di rumah klasik\n.\nKumpeni Coffee (@kum...          159
# 555  Siapa sangka sepeda kayuh ini berhasil disulap...         5300
# 556  Mungkin tempat ini adalah coffee shop pertama ...          264
# 557  Selain Joglonya, ada satu hal lagi yg cukup me...          221
#
#      comments_count           posted_at                 scraped_at  \
# 0                 0 2026-01-18 19:20:33 2026-01-19 02:51:22.221965
# 1                 2 2026-01-16 17:39:30 2026-01-19 02:51:22.240244
# 2                 0 2026-01-14 19:31:49 2026-01-19 02:51:22.247938
# 3                 0 2026-01-13 15:32:38 2026-01-19 02:51:22.254244
# 4                 0 2026-01-12 17:04:30 2026-01-19 02:51:22.258784
# ..              ...                 ...                        ...
# 553              10 2018-11-25 18:19:16 2026-01-19 02:51:24.947208
# 554               3 2018-07-21 19:24:17 2026-01-19 02:51:24.951691
# 555              64 2018-03-28 19:46:59 2026-01-19 02:51:24.956243
# 556              12 2018-03-09 18:43:19 2026-01-19 02:51:24.960577
# 557               7 2018-01-30 18:54:42 2026-01-19 02:51:24.964823
#
#                                               metadata
# 0    {'media_type': 8, 'product_type': 'carousel_co...
# 1           {'media_type': 2, 'product_type': 'clips'}
# 2    {'media_type': 8, 'product_type': 'carousel_co...
# 3           {'media_type': 2, 'product_type': 'clips'}
# 4    {'media_type': 8, 'product_type': 'carousel_co...
# ..                                                 ...
# 553  {'media_type': 8, 'product_type': 'carousel_co...
# 554  {'media_type': 8, 'product_type': 'carousel_co...
# 555  {'media_type': 8, 'product_type': 'carousel_co...
# 556  {'media_type': 8, 'product_type': 'carousel_co...
# 557  {'media_type': 8, 'product_type': 'carousel_co...
#
# [558 rows x 11 columns]

# %% [markdown]
# ---
#
# ## 5. Transform
#
# ### 5.1 Tujuan
#
# - Mengekstrak informasi dari caption
# - Menstandarkan format jam operasional
# - Membersihkan data dari missing value dan duplikasi
# - Ekstraksi kategori menu dan fungsi
# - Normalisasi teks
#
# ### 5.2 Tahapan
#
# 1. **Ekstraksi Informasi dari Caption** → menghasilkan kolom: `nama_tempat`, `jam_operasional`, `alamat`, `akun_instagram`
# 2. **Parsing Jam Operasional** → menghasilkan kolom: `open_time`, `close_time`, `is_24h`, `is_overnight`
# 3. **Normalisasi Caption** → menghasilkan kolom: `caption_norm`
# 4. **Ekstraksi Kota** → menghasilkan kolom: `kota`
# 5. **Reorder Kolom** → menyusun ulang urutan kolom
# 6. **Ekstraksi Kategori Menu & Fungsi** → menghasilkan kolom: `menu_category`, `function_category`
# 7. **Pembersihan Data Akhir** → menghapus null berdasarkan `jam_operasional`, menghapus duplikat berdasarkan `nama_tempat`, membersihkan emoji
#
# **Hasil:** Dataset terstruktur siap analisis

# %%
def extract_caption_info(caption):
    if pd.isna(caption):
        return pd.Series([None, None, None, None])

    # Normalisasi dash
    text = re.sub(r"[—–−]+", "-", caption)

    # Pisahkan baris
    lines = [
        l.strip()
        for l in text.split("\n")
        if l.strip() and not l.strip().startswith("#")
    ]

    nama_tempat = None
    jam_buka = None
    alamat = None
    akun_instagram = []

    if re.search(r"\b(buka|open)\s*24\s*(jam|hours|hrs)\b", text.lower()):
        jam_buka = "24 Jam"

    # Kumpulkan akun IG
    for line in lines:
        akun_instagram.extend(re.findall(r"@[\w\.]+", line))

    # Identifikasi jam buka
    jam_idx = None
    if jam_buka is None:
        for i in range(len(lines) - 1, -1, -1):
            line = lines[i]
            low = line.lower()

            if re.search(r"\b24\s*(jam|hours|hrs)\b", low):
                jam_buka = "24 Jam"
                jam_idx = i
                break

            if any(k in low for k in [
                "cek story", "lihat story", "cek instagram", "follow story",
                "happy hour", "buy", "get", "free"
            ]):
                continue

            m = re.search(
                r"\d{1,2}[:\.]\d{2}\s*-\s*\d{1,2}[:\.]\d{2}",
                line
            )
            if m:
                jam_buka = m.group()
                jam_idx = i
                break

    # Nama Tempat (sebelum jam)
    if jam_idx is not None:
        for j in range(jam_idx - 1, -1, -1):
            kandidat = lines[j]

            if "@" in kandidat:
                kandidat = kandidat.split("@")[0].strip()

            kandidat = re.sub(r"[\(\[\{]\s*$", "", kandidat).strip()
            kandidat = re.sub(r"[^\w\s]+$", "", kandidat).strip()

            if (
                kandidat
                and len(kandidat.split()) <= 8
                and not re.search(r"\d{1,2}[:\.]\d{2}", kandidat)
            ):
                nama_tempat = kandidat
                break

    if nama_tempat is None and jam_buka == "24 Jam":
        for line in lines:
            if "@" in line:
                kandidat = line.split("@")[0].strip()
                kandidat = re.sub(r"[^\w\s]+$", "", kandidat).strip()
                if kandidat:
                    nama_tempat = kandidat
                    break

    # Alamat (setelah jam atau paling bawah)
    if jam_idx is not None and jam_idx + 1 < len(lines):
        alamat = lines[jam_idx + 1]

    if alamat is None:
        for line in reversed(lines):
            if any(k in line.lower() for k in [
                "jl", "jalan", "kec", "kecamatan",
                "kota", "kab", "sleman", "yogyakarta",
                "yk", "gg", "diy", "bantul",
                "palagan", "ngaglik", "ploso", "sinduharjo"
            ]):
                alamat = line
                break

    if jam_buka is None and alamat is None:
        return pd.Series([None, None, None, None])

    return pd.Series([
        nama_tempat,
        jam_buka,
        alamat,
        ", ".join(sorted(set(akun_instagram))) if akun_instagram else None
    ])

# Apply ke dataframe
posts[["nama_tempat", "jam_operasional", "alamat", "akun_instagram"]] = (
    posts["caption"].apply(extract_caption_info)
)

# %%
data = posts[['caption', 'nama_tempat', 'jam_operasional', 'alamat', 'akun_instagram']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   caption          558 non-null    object
#  1   nama_tempat      426 non-null    object
#  2   jam_operasional  427 non-null    object
#  3   alamat           543 non-null    object
#  4   akun_instagram   526 non-null    object
# dtypes: object(5)
# memory usage: 21.9+ KB

# %%
# Hapus missing values
# data.dropna(inplace=True)

# Hapus duplikat
data.drop_duplicates(inplace=True)

# Reset index
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#                                                caption  \
# 0    Seriussn waktu itu pas lewat kirain gedung nik...
# 1    Seriusan coffee shop baru 24 jam dari Bandung ...
# 2    Baru di Jogja - Artisan bakery & coffee esteti...
# 3    Cold ‘N Brew baru aja buka cabangnya di Maliob...
# 4    Baru lagi di Jogja! Coffee & dining artistik a...
# ..                                                 ...
# 553  Kalau kamu lagi pengen ngopi enak tempat ini b...
# 554  Ngopi di rumah klasik\n.\nKumpeni Coffee (@kum...
# 555  Siapa sangka sepeda kayuh ini berhasil disulap...
# 556  Mungkin tempat ini adalah coffee shop pertama ...
# 557  Selain Joglonya, ada satu hal lagi yg cukup me...
#
#                        nama_tempat jam_operasional  \
# 0    Lyon’s Cafe & Coworking Space          24 Jam
# 1                  Beri Kopi Jogja          24 Jam
# 2        Elder On The Table - EOTB   07:00 - 22:00
# 3           Seperti cabang lainnya          24 Jam
# 4              Waktu Luang De Loji   10:00 - 22:00
# ..                             ...             ...
# 553                           None            None
# 554                           None            None
# 555                           None            None
# 556                           None            None
# 557                           None            None
#
#                                                 alamat  \
# 0    Jl. Nyi Tjondrolukito No 82, Kutu Dukuh, Sindu...
# 1               Dero, Condongcatur, Sleman, Yogyakarta
# 2                      Jl. Kranggan, Jetis, Yogyakarta
# 3                              Jl. Mataram, Yogyakarta
# 4    Jl. Panembahan Senopati, Prawirodirjan, Kec. G...
# ..                                                 ...
# 553                     Jl. Cempaka, Condong Catur, Yk
# 554                          Jl. Nyi Ahmad Dahlan, Yk.
# 555  UPDATE: Saat ini sudah tidak menggunakan seped...
# 556                    Jl. Kaliurang km 5, Pogung Baru
# 557                      Jl. LPMP, Kalasan, Sleman, Yk
#
#                           akun_instagram
# 0                          @lyonscafe.co
# 1                        @berikopi.jogja
# 2    @elder.onthetable, @elderpatisserie
# 3                             @coldnbrew
# 4                     @waktuluang.deloji
# ..                                   ...
# 553                                 None
# 554                      @kumpeni.coffee
# 555                                 None
# 556                         @dasmu.works
# 557                      @lituhayucoffee
#
# [558 rows x 5 columns]

# %%
def parse_jam_buka(jam_buka):
    if pd.isna(jam_buka):
        return pd.Series([None, None, False, False])

    jb = jam_buka.lower().strip()

    # Kasus 24 Jam
    if re.fullmatch(r"24\s*jam", jb):
        return pd.Series([
            time(0, 0),        # open_time
            time(23, 59),      # close_time 
            True,              # is_24h
            False              # is_overnight
        ])

    # Kasus non 24 jam
    m = re.match(
        r"(\d{1,2})[:\.](\d{2})\s*-\s*(\d{1,2})[:\.](\d{2})",
        jam_buka
    )

    if m:
        h1, m1, h2, m2 = map(int, m.groups())

        open_time = time(h1, m1)

        if h2 == 24 and m2 == 0:
            close_time = time(23, 59)
            is_overnight = False
        else:
            close_time = time(h2, m2)
            is_overnight = (h2*60 + m2) < (h1*60 + m1)

        return pd.Series([
            open_time,
            close_time,
            False,
            is_overnight
        ])

    return pd.Series([None, None, False, False])

data[
    ["open_time", "close_time", "is_24h", "is_overnight"]
] = data["jam_operasional"].apply(parse_jam_buka)

# Format open_time dan close_time ke HH:MM
data["open_time"] = data["open_time"].apply(lambda t: t.strftime("%H:%M") if pd.notna(t) else None)
data["close_time"] = data["close_time"].apply(lambda t: t.strftime("%H:%M") if pd.notna(t) else None)

# %%
def normalize_caption_post(text):
    if pd.isna(text):
        return None

    # Lowercase
    text = text.lower()

    # Normalisasi dash
    text = re.sub(r"[—–−]+", "-", text)

    # Hapus emoji
    text = re.sub(
        r"[\U00010000-\U0010FFFF]",
        "",
        text
    )

    # Hapus url
    text = re.sub(r"http\S+|www\S+", "", text)


    # Hapus karakter
    text = re.sub(r"[^a-z0-9@#\n\.\,\-\s]", " ", text)

    # Normalisasi spasi
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n\s*\n+", "\n", text)

    return text.strip()


data["caption_norm"] = data["caption"].apply(normalize_caption_post)

# %%
def extract_kota(alamat):
    if pd.isna(alamat):
        return None
    alamat = alamat.lower()
    if "sleman" in alamat:
        return "Sleman"
    if "bantul" in alamat:
        return "Bantul"
    if "kulon progo" in alamat:
        return "Kulon Progo"
    if "kulonprogo" in alamat:
        return "Kulon Progo"
    if "gunungkidul" in alamat:
        return "Gunungkidul"
    if "yogyakarta" in alamat or "jogja" in alamat or "yk" in alamat:
        return "Yogyakarta"
    return "Lainnya"

data["kota"] = data["alamat"].apply(extract_kota)

# %%
# Letakkan kolom caption_norm setelah caption
data = data[[
    "caption", "caption_norm",
    "nama_tempat", "jam_operasional",
    "alamat", "kota", "akun_instagram", "open_time", "close_time", "is_24h", "is_overnight"
]]

# %%
# Kata kunci

MENU_KEYWORDS = {
    "kopi": [
        "kopi", "espresso", "latte", "americano",
        "cappuccino", "manual brew", "v60",
        "arabica", "robusta"
    ],
    "makanan": [
        "makan", "rice bowl", "pasta",
        "steak", "brunch", "lunch", "dinner",
        "nasi", "ayam", "beverages", "eatery"
    ],
    "dessert": [
        "cake", "croissant", "pastry",
        "dessert", "brownies", "donut", "croffle",
        "es krim"
    ]
}

FUNCTION_KEYWORDS = {
    "wfc": [
        "wfc", "kerja", "laptop",
        "colokan", "wifi", "nugas", "working"
    ],
    "hangout": [
        "nongkrong", "hangout", "bersantai",
        "ngopi santai", "kumpul", "senja", "nyore"
    ],
    "dating": [
        "romantis", "couple",
        "date", "malam mingguan"
    ]
}

# fungsi pembersihan teks
def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"[^\w\s]", " ", text)
    return text

# elekstraksi kategori menu
def extract_menu_category(caption):
    text = clean_text(caption)
    labels = []
    for category, keywords in MENU_KEYWORDS.items():
        if any(kw in text for kw in keywords):
            labels.append(category)
    return labels

# ekstraksi kategori fungsi
def extract_function_category(caption):
    text = clean_text(caption)
    labels = []
    for category, keywords in FUNCTION_KEYWORDS.items():
        if any(kw in text for kw in keywords):
            labels.append(category)
    return labels

# label dominan (opsional)
def dominant_label(labels):
    return labels[0] if labels else None

# apply ke dataframe
data["menu_category"] = data["caption"].apply(extract_menu_category)
data["function_category"] = data["caption"].apply(extract_function_category)

# data["menu_main"] = data["menu_category"].apply(dominant_label)
# data["function_main"] = data["function_category"].apply(dominant_label)

# kolom boolean (opsional)
# for cat in MENU_KEYWORDS:
#     data[f"menu_{cat}"] = data["menu_category"].apply(lambda x: cat in x)

# for cat in FUNCTION_KEYWORDS:
#     data[f"func_{cat}"] = data["function_category"].apply(lambda x: cat in x)

# %%
# hapus missing value 
data.dropna(subset=['jam_operasional'], inplace=True)

# hapus duplikat berdasarkan nama_tempat
data.drop_duplicates(subset=['nama_tempat'], inplace=True)

# hapus emoji di alamat
data['alamat'] = data['alamat'].apply(lambda x: re.sub(r'[\U00010000-\U0010FFFF]', '', x) if pd.notna(x) else x)

# %%
data
# Out:
#                                                caption  \
# 0    Seriussn waktu itu pas lewat kirain gedung nik...
# 1    Seriusan coffee shop baru 24 jam dari Bandung ...
# 2    Baru di Jogja - Artisan bakery & coffee esteti...
# 3    Cold ‘N Brew baru aja buka cabangnya di Maliob...
# 4    Baru lagi di Jogja! Coffee & dining artistik a...
# ..                                                 ...
# 476  Lunaria, coffee and eatery estetik baru di Ged...
# 477  Kolokial Coffee, coffee shop bertema medieval ...
# 478  Merindu bersama di Ruang Rindu Coffee\n\nCoffe...
# 481  Kastem Space Gantara, penyegaran coffee shop d...
# 538  Beberapa hari kemarin kami iseng pengen ngopi ...
#
#                                           caption_norm  \
# 0    seriussn waktu itu pas lewat kirain gedung nik...
# 1    seriusan coffee shop baru 24 jam dari bandung ...
# 2    baru di jogja - artisan bakery coffee estetik ...
# 3    cold n brew baru aja buka cabangnya di maliobo...
# 4    baru lagi di jogja coffee dining artistik aest...
# ..                                                 ...
# 476  lunaria, coffee and eatery estetik baru di ged...
# 477  kolokial coffee, coffee shop bertema medieval ...
# 478  merindu bersama di ruang rindu coffee\ncoffee ...
# 481  kastem space gantara, penyegaran coffee shop d...
# 538  beberapa hari kemarin kami iseng pengen ngopi ...
#
#                        nama_tempat jam_operasional  \
# 0    Lyon’s Cafe & Coworking Space          24 Jam
# 1                  Beri Kopi Jogja          24 Jam
# 2        Elder On The Table - EOTB   07:00 - 22:00
# 3           Seperti cabang lainnya          24 Jam
# 4              Waktu Luang De Loji   10:00 - 22:00
# ..                             ...             ...
# 476                 Lunaria Coffee   08:00 - 22:00
# 477                Kolokial Coffee     09:00-22.00
# 478             Ruang Rindu Coffee   08:00 - 01:00
# 481         Kasteman Space Gantara   10:00 - 24.00
# 538               Inspira Roasters          24 Jam
#
#                                                 alamat        kota  \
# 0    Jl. Nyi Tjondrolukito No 82, Kutu Dukuh, Sindu...      Sleman
# 1               Dero, Condongcatur, Sleman, Yogyakarta      Sleman
# 2                      Jl. Kranggan, Jetis, Yogyakarta  Yogyakarta
# 3                              Jl. Mataram, Yogyakarta  Yogyakarta
# 4    Jl. Panembahan Senopati, Prawirodirjan, Kec. G...  Yogyakarta
# ..                                                 ...         ...
# 476          Jl. Gedongkiwo No.29 (Pojok Beteng Kulon)     Lainnya
# 477  Jl. Affandi No.30, Condongcatur, Depok, Kabupa...      Sleman
# 478  Jl. Perumnas, Kledokan, Caturtunggal, Depok, S...      Sleman
# 481  Jl. Lowanu, Sorosutan, Umbulharjo, Kota Yogyak...  Yogyakarta
# 538  Gaia Cosmo Hotel, Jl. Ipda Tut Harsono, Muja M...  Yogyakarta
#
#                           akun_instagram open_time close_time  is_24h  \
# 0                          @lyonscafe.co     00:00      23:59    True
# 1                        @berikopi.jogja     00:00      23:59    True
# 2    @elder.onthetable, @elderpatisserie     07:00      22:00   False
# 3                             @coldnbrew     00:00      23:59    True
# 4                     @waktuluang.deloji     10:00      22:00   False
# ..                                   ...       ...        ...     ...
# 476                       @lunariacoffee     08:00      22:00   False
# 477                   @kolokial.coffeeyk     09:00      22:00   False
# 478                      @kopiruangrindu     08:00      01:00   False
# 481                 @kastemspace_gantara     10:00      23:59   False
# 538                     @inspiraroasters     00:00      23:59    True
#
#      is_overnight    menu_category       function_category
# 0           False           [kopi]                   [wfc]
# 1           False  [kopi, makanan]  [wfc, hangout, dating]
# 2           False  [kopi, dessert]                [dating]
# 3           False               []                   [wfc]
# 4           False        [makanan]                [dating]
# ..            ...              ...                     ...
# 476         False  [kopi, makanan]          [wfc, hangout]
# 477         False        [makanan]               [hangout]
# 478          True  [kopi, makanan]  [wfc, hangout, dating]
# 481         False           [kopi]                   [wfc]
# 538         False           [kopi]                      []
#
# [376 rows x 13 columns]

# %% [markdown]
# ---
#
# ## 6. Load
#
# ### 6.1 Output Files
#
# **File:** `preprocessed_posts.csv`, `preprocessed_posts.xlsx`, dan tabel `preprocessed_posts` di PostgreSQL
#
# ### 6.2 Struktur Data Output
#
# | Kolom | Tipe | Deskripsi |
# |-------|------|-----------|
# | `caption` | string | Caption Instagram asli |
# | `caption_norm` | string | Caption yang sudah dinormalisasi (lowercase, hapus emoji, hapus URL, hapus karakter spesial) |
# | `nama_tempat` | string | Nama coffee shop yang di-ekstrak dari caption |
# | `jam_operasional` | string | Jam operasional dalam format teks (e.g. "09:00-22:00" atau "24 Jam") |
# | `alamat` | string | Alamat coffee shop yang di-ekstrak dari caption |
# | `kota` | string | Kota (Sleman, Bantul, Kulon Progo, Gunungkidul, Yogyakarta, Lainnya) |
# | `akun_instagram` | string | Instagram accounts yang di-mention (comma-separated) |
# | `open_time` | string | Jam buka dalam format HH:MM |
# | `close_time` | string | Jam tutup dalam format HH:MM |
# | `is_24h` | bool | Flag untuk operasional 24 jam |
# | `is_overnight` | bool | Flag untuk operasional melebihi tengah malam |
# | `menu_category` | list | Kategori menu yang ditemukan (kopi, makanan, dessert) |
# | `function_category` | list | Kategori fungsi yang ditemukan (wfc, hangout, dating) |

# %%
# save ke csv
data.to_csv("preprocessed_posts.csv", index=False)

# save ke excel
data.to_excel("preprocessed_posts.xlsx", index=False)

# save ke database
data.to_sql('preprocessed_posts', engine, if_exists='replace', index=False)
